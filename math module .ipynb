# %%
x =sqrt(49)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x =sqrt(49)
#
# NameError: name 'sqrt' is not defined

# %%
import math
math.sqrt(49)
# Out:
# 7.0

# %%
import math
math.sqrt(49)
round(math.sqrt(49))
# Out:
# 7

# %%
pi=3.14
pi
# Out:
# 3.14

# %%
pi=14.7
pi
# Out:
# 14.7

# %%
math.pow(6,5)
# Out:
# 7776.0

# %%
import math as n

print(n.pow(9,2))
print(n.floor(4.5))
print(n.ceil(6.9))
# Out:
# 81.0
# 4
# 7

# %%
import math
num=3.2
print("ceil value", math.ceil(num))
print("floor value", math.floor(num))
# Out:
# ceil value 4
# floor value 3

# %%
import math

num=4.6

print("floor value", math.floor(num))
print('ceil value", math.ceil(num))
# Out:
#   Cell In[19], line 6
#     print('ceil value", math.ceil(num))
#           ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
import math

num=4.6
print("floor value", math.floor(num))
print("ceil value", math.ceil(num))
# Out:
# floor value 4
# ceil value 5

# %%
import math

base=2
pow=8
result=math.pow(base, pow)
print("Pow:", result)
print("Base:", result)
# Out:
# Pow: 256.0
# Base: 256.0

# %%
import math

num=12
result =math.sqrt(num)
print("Square root:", result)
# Out:
# Square root: 3.4641016151377544

# %%
from math import sqrt,pow,floor,ceil

print(pow(4,6))
print(sqrt(20))
print(floor(4.6))
print(ceil(3.5))
# Out:
# 4096.0
# 4.47213595499958
# 4
# 4

# %%
from math import *

print(pow(9,5))
print(sqrt(45))
print(ceil(4.9))
print(floor(9.2))
# Out:
# 59049.0
# 6.708203932499369
# 5
# 9

# %% [markdown]
# Input()

# %%
x = input()
x
# Out:
#  hello myself aisha
# 'hello myself aisha'

# %%
x1 = input()
y1 = input()

z =x1+y1
print(z)
# Out:
#  72
#  97
# 7297

# %%
type(y1)
# Out:
# str

# %%
x = int(input())
y = int(input())
z=x+y
print(z)
# Out:
#  46
#  687
# 733

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# int

# %%
type(z)
# Out:
# int

# %%
x1 = int(input('Enter the 1st number'))
y1 = int(input('Enter the 2nd number'))
sum = x1+y1
print(sum)
# Out:
# Enter the 1st number 2345
# Enter the 2nd number 5678
# 8023

# %%
x1 = input('user_name')
y1 = input('password')
add  =x1+y1
print(add)
# Out:
# user_name aisha
# password 222222
# aisha222222

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string hello
# hello

# %%
print(st[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(st[3])
#
# NameError: name 'st' is not defined

# %%
st = input('enter a string')[0]
print(st)
# Out:
# enter a string nareshit
# n

# %%
st = input('enter a sttring')[3:]
print(st)
# Out:
# enter a sttring 567894567
# 894567

# %%
st= input('enter a string')
print(st)
# Out:
# enter a string 30+34-5
# 30+34-5

# %%
result = eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 45+67-45
# 67

# %%
num = int(input("Enter a number:"))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number: 45687
# Odd number

# %%
a = float(input("Enter Principal amount:"))
b = float(input("Enter Principal amount:"))
c = float(input("Enter Principal amount:"))

si = (a*b*c) / 100
print("Simple interest is:",si)
# Out:
# Enter Principal amount: 213
# Enter Principal amount: 456
# Enter Principal amount: 975709
# Simple interest is: 947686637.52
