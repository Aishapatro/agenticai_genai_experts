# %%
a=10
b=20
a 
b
# Out:
# 20

# %%
a=10 
b=20 
print(a) 
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(20)
print('python')
print('10,20,python')
# Out:
# 10
# 20
# python
# 10,20,python

# %%
num1=10
num2=20
num3=num1+num2
print(num3)
# Out:
# 30

# %% [markdown]
# # Print result with string

# %%
num1=10
num=20
num3=num1+num2
print(num3)
# Out:
# 50

# %%
name='aisharani'
age=20
city='hyd'
print(name)
print(age)
print(city)
# Out:
# aisharani
# 20
# hyd

# %%
print('My name is',name,'and i am',age,'years old from',city)
# Out:
# My name is aisharani and i am 20 years old from hyd

# %% [markdown]
# #Print Format Method

# %%
num1=30
num2=40
num3=num1+num2
print('The addition of {} and {} is= {}'.format(num1,num2,num3))
# Out:
# The addition of 30 and 40 is= 70

# %%
name='Python'
age=20
city='hyd'
#hello my name is python and i am 10 year old from hyd
print(name)
print(age)
print(city)
# Out:
# Python
# 20
# hyd

# %%
print('hello my name is{},and iam {} years old from {}'.format(name,age,city))
# Out:
# hello my name isPython,and iam 20 years old from hyd

# %%
num1=120
num2=20
num3=44
avg=(num1+num2+num3)/3
avg1=round((num1+num2+num3)/3,2)
print('The average of {},{},and{} is={} or{}'.format(num1,num2,num3,avg,avg1))
# Out:
# The average of 120,20,and44 is=61.333333333333336 or61.33

# %%
round(avg,2)
# Out:
# 61.33

# %%
num1=40
num2=50
num3=60
add=num1+num2+num3
print(f'The addition of {40},{50} and {60} is = {add}')
# Out:
# The addition of 40,50 and 60 is = 150

# %%
print(f'hello my name is {name},and i am{age} year old,from {city}.')
# Out:
# hello my name is Python,and i am20 year old,from hyd.

# %%
num1=100
num2=30
num3=444
avg=round((num1+num2+num3)/3,2)
avg
# Out:
# 191.33

# %%
print(f'The average of{num1},{num2} and {num3} is ={avg}')
# Out:
# The average of100,30 and 444 is =191.33

# %%
num1=10
num2=40
add=num1+num2
print('The addition of',num1,'and',num2,'is=',add)
print('The addition of {} and {} is={}'.format(num1,num2,add))
print(f'The addition of {num1} and {num2} is ={add}')
# Out:
# The addition of 10 and 40 is= 50
# The addition of 10 and 40 is=50
# The addition of 10 and 40 is =50

# %% [markdown]
# # End statement

# %%
print('hello')
print('good morning')
# Out:
# hello
# good morning

# %%
print('hello',end='')
print('world good day')
# Out:
# helloworld good day

# %%
print('hello','hai','how are you',sep='-->')
# Out:
# hello-->hai-->how are you

# %%
print('hello','hai','how are you',sep='@')
# Out:
# hello@hai@how are you

# %%
print('hello','hai','how are you',sep='&')
# Out:
# hello&hai&how are you

# %%
print('hello','hai','how are you',sep='')
# Out:
# hellohaihow are you

# %%
print(3,'.') # . is far from 3 so here we will use sep method
# Out:
# 3 .

# %%
print(3,'.',sep='')
# Out:
# 3.

# %%
print(1,2,end='')
print(3,'.',sep='')
# Out:
# 1 23.
