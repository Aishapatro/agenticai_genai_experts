# %%
~11
# Out:
# -12

# %%
~34
# Out:
# -35

# %%
~23
# Out:
# -24

# %% [markdown]
# # and &

# %%
12 & 13
# Out:
# 12

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(13)
# Out:
# '0b1101'

# %%
12 & 13
# Out:
# 12

# %% [markdown]
# # Bitwise or

# %%
12  | 13
# Out:
# 13

# %% [markdown]
# # xor^

# %%
12 ^ 13
# Out:
# 1

# %%
15^16
# Out:
# 31

# %% [markdown]
# # Left Shift <<

# %%
12<<1
# Out:
# 24

# %%
12<<2
# Out:
# 48

# %%
11<<3
# Out:
# 88

# %%
17<<7
# Out:
# 2176

# %% [markdown]
# # Right shift >>

# %%
12>>2
# Out:
# 3

# %%
67>>7
# Out:
# 0

# %%
98>>8
# Out:
# 0
