# %%
if True:  #inentiation is always 4 spaces
    print('Data Science')
# Out:
# Data Science

# %%
if True:  #indentiation is always 4 spaces
    print('Data Science')
    print('need to spend everyday 3-4hr')
# Out:
# Data Science
# need to spend everyday 3-4hr

# %%
if False:  #indentiation is always 4 spaces
    print('Data Science')
print('good bye')
# Out:
# good bye

# %%
if True:  #indentiation  is always 4 spaces
    print('Data Science')
print('good bye')
# Out:
# Data Science
# good bye

# %%
if True:  #indentiation is always 4 space
    print('Data Science')
else:
    print('good bye')
# Out:
# Data Science

# %%
if False:  #indentiation is always 4 space
    print('Data Science')
else:
    print('good bye')
# Out:
# good bye

# %% [markdown]
# # Even or Odd

# %%
x=4
r=x%2

if r==0:
    print('Even number')
# Out:
# Even number

# %%
x=5
r=x%2

if r==0:
    print('Even number')

# %%
x=9
r=x%2

if r==0:
    print('Even number')

if r==1:
    print('Odd number')
# Out:
# Odd number

# %%
x=8
r=x%2

if r==0:
    print('Even number')
else:
    print('Odd number')
# Out:
# Even number

# %%
x=5
r=x%2

if r==0:
    print('Even number')
print('odd number')
# Out:
# odd number

# %%
x=4
r=x%2

if r==0:
  print('Even number')
print('odd number')
# Out:
# Even number
# odd number

# %%
x=4
r=x%2

if r==0:
  print('Even number')
else:
    print('odd number')
# Out:
# Even number

# %%
x=17
r=x%2

if r==0:
    print('Even number')
    if x>5:
        print('greater number')

else:
    print('odd number')
# Out:
# odd number

# %%
x=4
r=x%2

if r==0:
    print('Even number')
    if x>5:
        print('greater number')
else:
    print('odd number')
# Out:
# Even number

# %%
x=6
r=x%2

if r==0:
    print('Even number')
    if x>5:
        print('greater number')
else:
    print('odd number')
# Out:
# Even number
# greater number

# %%
x=2
r=x%2

if r==0:
    print('Even number')

    if x>5:
        print('greater number')
    else:
        print('not greater')

else:
    print('odd number')
# Out:
# Even number
# not greater

# %%
year=int(input("Enter a year:"))

if(year%4==0 and year%100!=0)or(year%400==0):
         print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year: 34578
# Not a Leap Year

# %%
x=5
r=x%2

if r==0:
    print('Even number')
else:
    print('odd number')
# Out:
# odd number

# %%
x=4
r=x%2  

if r==0:
    print('Even number')

if r==1:
    print('odd number')

if r==2:
    print('even number')
# Out:
# Even number

# %%
x=1

if x==1:
    print('one')
if x==2:
    print('Two')
if x==3:
    print('Three')
if x==4:
    print('four')
# Out:
# one

# %%
x=3
r=x%2

if r==0:
    print('Even number')
    if x>5:
        print('greater number')
        
else:
    print('odd number')
# Out:
# odd number

# %%
x=4
r=x%2  

if r==0:
    print('Even number')
    if x>5:
        print('greater number')

else:
    print('odd number')
# Out:
# Even number

# %%
x=4
r=x%2

if r==0:
    print('Even number')

    if x>5:
        print('greater number')

    else:
        print('number is lesser number')

else:
    print('odd number')
# Out:
# Even number
# number is lesser number

# %%
x=4

if(x==1):
    print('one')
elif(x==2):
    print('Two')
elif(x==3):
    print('Three')
elif(x==4):
    print('four')
# Out:
# four

# %%
x=7

if(x==1):
    print('one')
elif(x==2):
    print('Two')
elif(x==3):
    print('Three')
elif(x==4):
    print('four')

# %%
x=7

if(x==1):
    print('one')
elif(x==2):
    print('Two')
elif(x==3):
    print('Three')
elif(x==4):
    print('four')

else:
    print('number not found')
# Out:
# number not found
