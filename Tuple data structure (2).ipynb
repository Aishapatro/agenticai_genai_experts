# %% [markdown]
# # Tuple

# %%
t=()
t
# Out:
# ()

# %%
t1=(10,20,30,40,50,50)
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t2=(10,'aisha',1+2j,True,2.3)
t2
# Out:
# (10, 'aisha', (1+2j), True, 2.3)

# %%
print(t1)
print(t2)
# Out:
# (10, 20, 30, 40, 50, 50)
# (10, 'aisha', (1+2j), True, 2.3)

# %%
print(type(t1))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1.count(50)
# Out:
# 2

# %%
t1.index(10)
# Out:
# 0

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1[:4]
# Out:
# (10, 20, 30, 40)

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1[5]
# Out:
# 50

# %%
t1*3
# Out:
# (10, 20, 30, 40, 50, 50, 10, 20, 30, 40, 50, 50, 10, 20, 30, 40, 50, 50)

# %% [markdown]
# # Tuple Creation

# %%
t1=()
t1
# Out:
# ()

# %%
tup2=(30,4,56,789,975)
tup2
# Out:
# (30, 4, 56, 789, 975)

# %%
tup3=(20.33,45.7,12.34,56.97)
tup3
# Out:
# (20.33, 45.7, 12.34, 56.97)

# %%
tup4=('seven','eleven','six')
tup4
# Out:
# ('seven', 'eleven', 'six')

# %%
tup5=('Aisha',245,(6557,456,797),(556,884))
tup5
# Out:
# ('Aisha', 245, (6557, 456, 797), (556, 884))

# %%
tup6=(67,'Aisha',52.96)
tup6
# Out:
# (67, 'Aisha', 52.96)

# %%
tup7=('Aisha',212,[6557,456,797],[556,884],{'ranu','puja'},(7885,645,734))
tup7
# Out:
# ('Aisha',
#  212,
#  [6557, 456, 797],
#  [556, 884],
#  {'puja', 'ranu'},
#  (7885, 645, 734))

# %%
len(tup7)
# Out:
# 6

# %% [markdown]
# # Tuple Indexing

# %%
tup2[0]
# Out:
# 30

# %%
tup2[3]
# Out:
# 789

# %%
tup2[2]
# Out:
# 56

# %%
tup3[1]
# Out:
# 45.7

# %%
tup3[0]
# Out:
# 20.33

# %%
tup4[0]
# Out:
# 'seven'

# %%
tup4[0][0]
# Out:
# 's'

# %%
tup4[-1]
# Out:
# 'six'

# %%
tup4[-2]
# Out:
# 'eleven'

# %%
tup5[-1]
# Out:
# (556, 884)

# %%
tup6[0]
# Out:
# 67

# %%
tup6[-2]
# Out:
# 'Aisha'

# %%
tup7[-1]
# Out:
# (7885, 645, 734)

# %%
tup7[-2]
# Out:
# {'puja', 'ranu'}

# %%
tup7[-4]
# Out:
# [6557, 456, 797]

# %% [markdown]
# # Tuple Slicing

# %%
tuple=('one','two','three','four','five','six','seven','eight')
tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
tuple[0:0]
# Out:
# ()

# %%
tuple[0:2]
# Out:
# ('one', 'two')

# %%
tuple[0:3]
# Out:
# ('one', 'two', 'three')

# %%
tuple[1:5]
# Out:
# ('two', 'three', 'four', 'five')

# %%
tuple[2:5]
# Out:
# ('three', 'four', 'five')

# %%
tuple[1:7:2]
# Out:
# ('two', 'four', 'six')

# %%
tuple[3:8:3]
# Out:
# ('four', 'seven')

# %%
tuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
tuple[:6]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six')

# %%
tuple[:5]
# Out:
# ('one', 'two', 'three', 'four', 'five')

# %%
tuple[:2]
# Out:
# ('one', 'two')

# %%
tuple[3:]
# Out:
# ('four', 'five', 'six', 'seven', 'eight')

# %%
tuple[-3:]
# Out:
# ('six', 'seven', 'eight')

# %%
tuple[-2:]
# Out:
# ('seven', 'eight')

# %%
tuple[-1:]
# Out:
# ('eight',)

# %%
tuple[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %% [markdown]
# # Remove & change items

# %%
tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del tuple[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 del tuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
del tuple[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 del tuple[3]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
tuple[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 tuple[0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
del tuple

# %% [markdown]
# #  Loop through a tuple

# %%
tuple=('one','two','three','four','five','six','seven')
tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven')

# %%
for i in tuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven

# %%
for i in enumerate(tuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')

# %% [markdown]
# # Tuple Membership

# %%
tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven')

# %%
'one' in tuple
# Out:
# True

# %%
'three' in tuple
# Out:
# True

# %%
'eleven' in tuple
# Out:
# False

# %%
'ten' in tuple
# Out:
# False

# %%
if 'four' in tuple:
    print('four is present in the tuple')
else:
    print('four is not present in the tuple')
# Out:
# four is present in the tuple

# %%
if'ten' in tuple:
    print('ten is present in the tuple')
else:
    print('ten is not present in the tuple')
# Out:
# ten is not present in the tuple

# %% [markdown]
# # Index Position

# %%
tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven')

# %%
tuple.index('one')
# Out:
# 0

# %%
tuple.index('five')
# Out:
# 4

# %%
tuple.index('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 tuple.index('ten')
#
# ValueError: tuple.index(x): x not in tuple

# %%
tuple.index('six')
# Out:
# 5

# %%
tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven')

# %%
tuple1.index('two')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 tuple1.index('two')
#
# NameError: name 'tuple1' is not defined

# %%
tuple1=('one','two','three','four','five','six','seven')
tuple1
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven')

# %%
tuple1.index('one')
# Out:
# 0

# %%
tuple1.index('seven')
# Out:
# 6

# %%
tuple.index('five')
# Out:
# 4

# %% [markdown]
# # Sorting

# %%
tuple2=(34,76,45,85,96,75,26)
tuple2
# Out:
# (34, 76, 45, 85, 96, 75, 26)

# %%
sorted(tuple2)
# Out:
# [26, 34, 45, 75, 76, 85, 96]

# %%
sorted(tuple2,reverse=True)
# Out:
# [96, 85, 76, 75, 45, 34, 26]

# %%
sorted(tuple2,reverse=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sorted(tuple2,reverse=False)
#
# NameError: name 'tuple2' is not defined
